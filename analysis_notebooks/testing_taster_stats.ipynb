# %%
#* for data manipulation 
import pandas as pd 
import numpy as np 

import tiling_disk_plots as tdp
import tiling_disk_utils as tdu


#* for plotting: 
import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline
sns.set_theme(style="ticks")
sns.set_context("talk")
# %matplotlib inline

# %%
taster_meas = pd.DataFrame([56.342,
                56.342,
                56.363,
                56.372,
                56.378,
                56.372])

# %%
taster_meas = taster_meas.apply(lambda x: x*10**3)

# %%
taster_meas.keys()
# Out:
# RangeIndex(start=0, stop=1, step=1)

# %%
tdp.ts_hist(taster_meas, mode=0)
# Out:
# (<Figure size 504x432 with 1 Axes>,
#  <AxesSubplot:xlabel='z [µm]', ylabel='Probability'>)

# %%
taster_meas.describe()
# Out:
#                   0
# count      6.000000
# mean   56361.500000
# std       15.846135
# min    56342.000000
# 25%    56347.250000
# 50%    56367.500000
# 75%    56372.000000
# max    56378.000000

# %%
print(taster_meas.max() - taster_meas.min())
# Out:
# 0    36.0
# dtype: float64
